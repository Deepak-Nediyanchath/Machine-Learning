# %%
from sklearn.datasets import load_boston
import pandas as pd
df=load_boston()
data=pd.DataFrame(df.data, columns=df.feature_names)
data['Price']=df.target
data.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
# 10  0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467  5.0  311.0
# 11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267  5.0  311.0
# ...

# %% [markdown]
# # Linear Regression model

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

X=data.iloc[:,:-1]
y=data.loc[:,'Price']



model= LinearRegression()
linreg=cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=5)
mean_linreg=np.mean(linreg)
print(mean_linreg)
# Out:
# -37.13180746769922

# %% [markdown]
# # Ridge Regression model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
import numpy as np

ranges = np.linspace(0.1,100,1000)
lambda_grid={'alpha':ranges}

ridge=Ridge()
ridgeregression=GridSearchCV(ridge,param_grid=lambda_grid,scoring='neg_mean_squared_error',cv=5)
ridgeregression.fit(X,y)

print(ridgeregression.best_params_)
print(ridgeregression.best_score_)
# Out:
# {'alpha': 100.0}
# -29.90570194754033

# %% [markdown]
# # Lasso Regression model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
import numpy as np

ranges = np.linspace(0.1,100,1000)
lambda_grid={'alpha':ranges}

lasso=Lasso()
lassoregression=GridSearchCV(estimator=lasso,param_grid=lambda_grid,scoring='neg_mean_squared_error',cv=5)
lassoregression.fit(X,y)

print(lassoregression.best_params_)
print(lassoregression.best_score_)
# Out:
# {'alpha': 0.30000000000000004}
# -34.455042438750915

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.8,random_state=0)
prediction_lasso=lassoregression.predict(X_test)
prediction_ridge=ridgeregression.predict(X_test)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(y_test-prediction_lasso)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
sns.distplot(y_test-prediction_ridge)
# Out:
# <AxesSubplot:xlabel='Price'>
